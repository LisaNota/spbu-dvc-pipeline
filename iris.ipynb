# %% [markdown]
# # Iris with dvc

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

import seaborn as sns

# %%
# создадим csv-файл, чтобы расположить его в нашем хранилище
iris = datasets.load_iris()

iris_df = pd.DataFrame(iris['data'], columns=iris['feature_names'])
iris_df = pd.concat((iris_df, pd.DataFrame(iris['target'], columns=['target'])), axis=1)

iris_df.to_csv('iris.csv')
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
data = pd.read_csv('iris.csv', index_col=0) 

corr_matrix = data.corr()

sns.heatmap(corr_matrix, 
            annot=True, 
            cmap='coolwarm',  
            linewidths=0.5)  

plt.title('Матрица корреляций')
plt.show()

# %%
# анализ данных на пропуски
data.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64
